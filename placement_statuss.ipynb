# %%
#Placement Status using KNN

# %%
import pandas as pd

# %%
df=pd.read_csv('placementdata.csv')

# %%
print(df)
# Out:
#       StudentID  CGPA  Internships  Projects  Workshops/Certifications  \
# 0             1   7.5            1         1                         1
# 1             2   8.9            0         3                         2
# 2             3   7.3            1         2                         2
# 3             4   7.5            1         1                         2
# 4             5   8.3            1         2                         2
# ...         ...   ...          ...       ...                       ...
# 9995       9996   7.5            1         1                         2
# 9996       9997   7.4            0         1                         0
# 9997       9998   8.4            1         3                         0
# 9998       9999   8.9            0         3                         2
# 9999      10000   8.4            0         1                         1
#
#       AptitudeTestScore  SoftSkillsRating ExtracurricularActivities  \
# ...

# %%
df.shape
# Out:
# (10000, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   StudentID                  10000 non-null  int64
#  1   CGPA                       10000 non-null  float64
#  2   Internships                10000 non-null  int64
#  3   Projects                   10000 non-null  int64
#  4   Workshops/Certifications   10000 non-null  int64
#  5   AptitudeTestScore          10000 non-null  int64
#  6   SoftSkillsRating           10000 non-null  float64
#  7   ExtracurricularActivities  10000 non-null  object
#  8   PlacementTraining          10000 non-null  object
#  9   SSC_Marks                  10000 non-null  int64
#  10  HSC_Marks                  10000 non-null  int64
#  11  PlacementStatus            10000 non-null  object
# dtypes: float64(2), int64(7), object(3)
# memory usage: 937.6+ KB

# %%
df.head()
# Out:
#    StudentID  CGPA  Internships  Projects  Workshops/Certifications  \
# 0          1   7.5            1         1                         1
# 1          2   8.9            0         3                         2
# 2          3   7.3            1         2                         2
# 3          4   7.5            1         1                         2
# 4          5   8.3            1         2                         2
#
#    AptitudeTestScore  SoftSkillsRating ExtracurricularActivities  \
# 0                 65               4.4                        No
# 1                 90               4.0                       Yes
# 2                 82               4.8                       Yes
# 3                 85               4.4                       Yes
# 4                 86               4.5                       Yes
#
#   PlacementTraining  SSC_Marks  HSC_Marks PlacementStatus
# 0                No         61         79       NotPlaced
# ...

# %%
df['ExtracurricularActivities'].unique
# Out:
# <bound method Series.unique of 0        No
# 1       Yes
# 2       Yes
# 3       Yes
# 4       Yes
#        ...
# 9995    Yes
# 9996     No
# 9997    Yes
# 9998    Yes
# 9999     No
# Name: ExtracurricularActivities, Length: 10000, dtype: object>

# %%
df['PlacementTraining'].unique
# Out:
# <bound method Series.unique of 0        No
# 1       Yes
# 2        No
# 3       Yes
# 4       Yes
#        ...
# 9995     No
# 9996     No
# 9997    Yes
# 9998    Yes
# 9999     No
# Name: PlacementTraining, Length: 10000, dtype: object>

# %%
df['PlacementStatus'].unique
# Out:
# <bound method Series.unique of 0       NotPlaced
# 1          Placed
# 2       NotPlaced
# 3          Placed
# 4          Placed
#           ...
# 9995    NotPlaced
# 9996       Placed
# 9997       Placed
# 9998       Placed
# 9999    NotPlaced
# Name: PlacementStatus, Length: 10000, dtype: object>

# %%
#label encoding
from sklearn import preprocessing
label_encoder=preprocessing.LabelEncoder()
df['ExtracurricularActivities']=label_encoder.fit_transform(df['ExtracurricularActivities'])

# %%
#label encoding
from sklearn import preprocessing
label_encoder=preprocessing.LabelEncoder()
df['PlacementTraining']=label_encoder.fit_transform(df['PlacementTraining'])

# %%
#label encoding
from sklearn import preprocessing
label_encoder=preprocessing.LabelEncoder()
df['PlacementStatus']=label_encoder.fit_transform(df['PlacementStatus'])

# %%
x=df.drop('PlacementStatus',axis=1)
y=df['PlacementStatus']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.fit_transform(x_test)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model=KNeighborsClassifier(n_neighbors=24)

# %%
model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=24)

# %%
model.score(x_train,y_train)
# Out:
# 0.80675

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
y_pred=model.predict(x_test)

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 1, 1, 0])

# %%
y_test
# Out:
# 6252    0
# 4684    0
# 1731    0
# 4742    0
# 4521    1
#        ..
# 6412    0
# 8285    0
# 7853    1
# 1095    1
# 6929    0
# Name: PlacementStatus, Length: 2000, dtype: int64

# %%
print(accuracy_score(y_pred,y_test))
# Out:
# 0.794

# %%
import joblib
model=joblib.load('PlacementStatus_model')

from tkinter import *
from PIL import Image, ImageTk
import joblib
from tkinter import messagebox
import pandas as pd

# Create the main application window
root = Tk()
root.title("Placement Status")
root.geometry("1400x690+0+0")  # Set the size of the window
root.configure(bg="white")  # Set the background color to white

def predict():
    
        inputs ={
            'StudentID': int(StudentID_entry.get()),
            'CGPA':float(CGPA_entry.get()),
            'Internships': float(Internships_entry.get()),
            'Projects': int(Projects_entry.get()),
            'Workshops_Certifications': int(Workshops_Certifications_entry.get()),
            'AptitudeTestScore': int(AptitudeTestScore_entry.get()),
            'SoftSkillRating': float(SoftskillRating_entry.get()),
            'ExtracurricularActivities': int(ExtracurricularActivities_entry.get()),
            'PlacementTraining': int(PlacementTraining_entry.get()),
            'SSC_Marks': float(SSC_marks_entry.get()),
            'HSC_Marks': int(HSC_marks_entry.get()),
            
        }
        input_df = pd.DataFrame([inputs])
        prediction = model.predict(input_df)
        result='PlacementStatus'if prediction[0]==1 else 'Not Placed'
        messagebox.showinfo(result)
       

# Left frame for the image
left_frame = Frame(root, width=600, height=400, bg="white")
left_frame.pack(side=LEFT, fill=BOTH, expand=True)
Heading_label = Label(left_frame, text="PlacementTraining", font=("Arial", 30), bg="white")
Heading_label.grid(row=0, column=0, padx=10, pady=8, sticky=W)


image_path =  "placement_status.png"
img = Image.open(image_path)
img = img.resize((600, 500), Image.Resampling.LANCZOS)
photo = ImageTk.PhotoImage(img)
img_label = Label(left_frame, image=photo, bg="white")
img_label.grid(row=1,column=0,padx=10,pady=8)

# Right frame for input fields
right_frame = Frame(root, width=600, height=400, bg="white", bd=5, relief=SOLID)
right_frame.pack(side=RIGHT, fill=BOTH, expand=True, padx=20, pady=20)

StudentID_label = Label(right_frame, text="StudentID", font=("Arial", 10), bg="white")
StudentID_label.grid(row=0, column=0, padx=10, pady=8, sticky=W)
StudentID_entry = Entry(right_frame, width=30)
StudentID_entry.grid(row=0, column=1, padx=10, pady=8)

CGPA_label = Label(right_frame, text="CGPA", font=("Arial", 10), bg="white")
CGPA_label.grid(row=1, column=0, padx=10, pady=8, sticky=W)
CGPA_entry = Entry(right_frame, width=30)
CGPA_entry.grid(row=1, column=1, padx=10, pady=8)

Internships_label = Label(right_frame, text="Internships", font=("Arial", 10), bg="white")
Internships_label.grid(row=2, column=0, padx=10, pady=8, sticky=W)
Internships_entry = Entry(right_frame, width=30)
Internships_entry.grid(row=2, column=1, padx=10, pady=8)

Projects_label = Label(right_frame, text="Projects", font=("Arial", 10), bg="white")
Projects_label.grid(row=3, column=0, padx=10, pady=8, sticky=W)
Projects_entry = Entry(right_frame, width=30)
Projects_entry.grid(row=3, column=1, padx=10, pady=8)

Workshops_Certifications_label = Label(right_frame, text="WorkshopsCertifications", font=("Arial", 10), bg="white")
Workshops_Certifications_label.grid(row=4, column=0, padx=10, pady=8, sticky=W)
Workshops_Certifications_entry = Entry(right_frame, width=30)
Workshops_Certifications_entry.grid(row=4, column=1, padx=10, pady=8)

AptitudeTestScore_label = Label(right_frame, text="AptitudeTestScore", font=("Arial", 10), bg="white")
AptitudeTestScore_label.grid(row=5, column=0, padx=10, pady=8, sticky=W)
AptitudeTestScore_entry = Entry(right_frame, width=30)
AptitudeTestScore_entry.grid(row=5, column=1, padx=10, pady=8)

SoftskillRating_label = Label(right_frame, text="SoftskillRating", font=("Arial", 10), bg="white")
SoftskillRating_label.grid(row=6, column=0, padx=10, pady=8, sticky=W)
SoftskillRating_entry = Entry(right_frame, width=30)
SoftskillRating_entry.grid(row=6, column=1, padx=10, pady=8)

ExtracurricularActivities_label = Label(right_frame, text="ExtracurricularActivities", font=("Arial", 10), bg="white")
ExtracurricularActivities_label.grid(row=7, column=0, padx=10, pady=8, sticky=W)
ExtracurricularActivities_entry = Entry(right_frame, width=30)
ExtracurricularActivities_entry.grid(row=7, column=1, padx=10, pady=8)

PlacementTraining_label = Label(right_frame, text="PlacementTraining", font=("Arial", 10), bg="white")
PlacementTraining_label.grid(row=8, column=0, padx=10, pady=8, sticky=W)

PlacementTraining_entry = Entry(right_frame, width=30)
PlacementTraining_entry.grid(row=8, column=1, padx=10, pady=8)

SSC_marks_label = Label(right_frame, text="SSC MARKS", font=("Arial", 10), bg="white")
SSC_marks_label.grid(row=9, column=0, padx=10, pady=8, sticky=W)
SSC_marks_entry = Entry(right_frame, width=30)
SSC_marks_entry.grid(row=9, column=1, padx=10, pady=8)

HSC_marks_label = Label(right_frame, text="HSC MARKS", font=("Arial", 10), bg="white")
HSC_marks_label.grid(row=10, column=0, padx=10, pady=8, sticky=W)
HSC_marks_entry = Entry(right_frame, width=30)
HSC_marks_entry.grid(row=10, column=1, padx=10, pady=8)



predict_button = Button(right_frame, text="Predict", font=("Arial", 10), bg="lightblue", fg="black", command=predict)
predict_button.grid(row=11, column=0, columnspan=2, pady=20)

root.mainloop()
